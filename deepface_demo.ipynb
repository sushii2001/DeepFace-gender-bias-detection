# %% [markdown]
# ## Deepface Demo

# %%
# !pip install deepface
from deepface import DeepFace
from deepface_main_test_func import *

import matplotlib.pyplot as plt
import pandas as pd 
import csv
import random as rd

import os

params = {"ytick.color" : "w",
          "xtick.color" : "w",
          "axes.labelcolor" : "w",
          "axes.edgecolor" : "w"}
plt.rcParams.update(params)

unit_test_df = pd.read_csv('data/deepface_LFW_gender_csv/deepface_unittests.csv')

# Read results from Deepface benchmark test  
result_df = pd.read_csv('result/result_deepface.csv')
result_benchmark_gender_nonperturbed = pd.read_csv('result/deepface_benchmark_gender_nonperturbed.csv')
result_benchmark_gender_perturbed = pd.read_csv('result/deepface_benchmark_gender_perturbed.csv')

# Read results from Deepface GUI test
result_gui_face_recognition = pd.read_csv('result/deepface_gui_face_recognition.csv')
result_gui_gender = pd.read_csv('result/deepface_gui_gender.csv')

# %% [markdown]
# # Deepface Threshold results:

# %%
## Results based on https://youtu.be/i_MOwvhbLdI 
_vgg_face = {"Model": "VGGFace", "Accuracy": 89.28, "Precision": 97.41, "Recall": 80.71}
_facenet = {"Model": "FaceNet", "Accuracy": 98.21, "Precision": 100, "Recall": 96.42}
_openface = {"Model": "OpenFace", "Accuracy": 57.85, "Precision": 95.83, "Recall": 16.42}
_deepface = {"Model": "DeepFace", "Accuracy": 54.64, "Precision": 100, "Recall": 9.28}

models_results = [_facenet, _openface, _deepface]

result_model_df = pd.DataFrame([_vgg_face])
for model in models_results:
    result_model = pd.DataFrame([model])
    frames = [result_model_df, result_model]
    result_model_df = pd.concat(frames)

    result_model_df = result_model_df.reset_index()
    result_model_df.drop(columns=['index'], inplace=True)

result_model_df
# Out:
#       Model  Accuracy  Precision  Recall
# 0   VGGFace     89.28      97.41   80.71
# 1   FaceNet     98.21     100.00   96.42
# 2  OpenFace     57.85      95.83   16.42
# 3  DeepFace     54.64     100.00    9.28

# %% [markdown]
# ## Benchmark Results from Deepface:

# %%
# Deepface benchmark results: 
result_df
# Out:
#          Model Dataset  CM_ACC  Precision  Recall  Total Images    TP    TN  \
# 0   Facenet512     LFW    91.0       99.0    83.0          6000  2496  2974
# 1      Facenet     LFW    79.0      100.0    58.0          6000  1733  2992
# 2     VGG-Face     LFW    86.0       81.0    93.0          6000  2799  2334
# 3     OpenFace     LFW    56.0       86.0    15.0          6000   441  2929
# 4     DeepFace     LFW    64.0       76.0    41.0          6000  1225  2621
# 5      ArcFace     LFW    94.0       99.0    89.0          6000  2678  2966
# 6   Facenet512     LFW    91.0       99.0    84.0          2000   837   989
# 7      Facenet     LFW    73.0      100.0    46.0          2000   462  1000
# 8     VGG-Face     LFW    80.0       79.0    81.0          2000   805   785
# 9     OpenFace     LFW    56.0       98.0    11.0          2000   114   998
# 10    DeepFace     LFW    57.0       73.0    22.0          2000   219   918
# 11     ArcFace     LFW    90.0      100.0    80.0          2000   801   997
#
#      FP    FN  Undetected
# 0    26   504         0.0
# 1     8  1267         0.0
# 2   666   201         0.0
# 3    71  2559         0.0
# 4   379  1775         0.0
# 5    34   322         0.0
# 6    11   163         0.0
# 7     0   538         0.0
# 8   215   195         0.0
# 9     2   886         0.0
# 10   82   781         0.0
# 11    3   199         0.0

# %%
# Deepface benchmark with gender split: 
result_benchmark_gender_nonperturbed
# Out:
#          Model     Dataset  CM_ACC  Precision  Recall  Total Images  Gender  \
# 0   Facenet512  LFW_gender    92.0       97.0    85.0          1000    Male
# 1   Facenet512  LFW_gender    91.0      100.0    83.0          1000  Female
# 2      Facenet  LFW_gender    73.0      100.0    46.0          1000    Male
# 3      Facenet  LFW_gender    73.0      100.0    46.0          1000  Female
# 4     VGG-Face  LFW_gender    73.0       68.0    86.0          1000    Male
# 5     VGG-Face  LFW_gender    86.0       96.0    75.0          1000  Female
# 6     OpenFace  LFW_gender    53.0       94.0     6.0          1000    Male
# 7     OpenFace  LFW_gender    58.0      100.0    17.0          1000  Female
# 8     DeepFace  LFW_gender    56.0       65.0    23.0          1000    Male
# 9     DeepFace  LFW_gender    58.0       84.0    20.0          1000  Female
# 10     ArcFace  LFW_gender    90.0      100.0    81.0          1000    Male
# 11     ArcFace  LFW_gender    90.0      100.0    80.0          1000  Female
#
#      TP   TN   FP   FN  Undetected
# 0   426  489   11   74           0
# 1   414  500    0   86           0
# 2   232  500    0  268           0
# 3   232  500    0  268           0
# 4   429  300  200   71           0
# 5   374  485   15  126           0
# 6    31  498    2  469           0
# 7    83  500    0  417           0
# 8   117  438   62  383           0
# 9   102  480   20  398           0
# 10  403  498    2   97           0
# 11  398  499    1  102           0

# %%
# Deepface benchmark with gender split and perturbation: 
result_benchmark_gender_perturbed
# Out:
#          Model                  Dataset  CM_ACC  Precision  Recall  \
# 0   Facenet512  LFW_gender_makeup_heavy    87.0       94.0    80.0
# 1   Facenet512  LFW_gender_makeup_heavy    86.0       99.0    73.0
# 2      Facenet  LFW_gender_makeup_heavy    67.0      100.0    35.0
# 3      Facenet  LFW_gender_makeup_heavy    69.0      100.0    38.0
# 4     VGG-Face  LFW_gender_makeup_heavy    73.0       70.0    81.0
# 5     VGG-Face  LFW_gender_makeup_heavy    83.0       96.0    69.0
# 6     OpenFace  LFW_gender_makeup_heavy    54.0       95.0     8.0
# 7     OpenFace  LFW_gender_makeup_heavy    56.0      100.0    12.0
# 8     DeepFace  LFW_gender_makeup_heavy    55.0       62.0    25.0
# 9     DeepFace  LFW_gender_makeup_heavy    58.0       79.0    22.0
# 10     ArcFace  LFW_gender_makeup_heavy    87.0       98.0    75.0
# 11     ArcFace  LFW_gender_makeup_heavy    86.0       99.0    73.0
# 12  Facenet512  LFW_gender_makeup_light    89.0       94.0    83.0
# 13  Facenet512  LFW_gender_makeup_light    90.0      100.0    81.0
# 14     Facenet  LFW_gender_makeup_light    72.0      100.0    44.0
# 15     Facenet  LFW_gender_makeup_light    72.0      100.0    43.0
# 16    VGG-Face  LFW_gender_makeup_light    69.0       64.0    84.0
# 17    VGG-Face  LFW_gender_makeup_light    83.0       93.0    72.0
# 18    OpenFace  LFW_gender_makeup_light    52.0       88.0     4.0
# 19    OpenFace  LFW_gender_makeup_light    60.0      100.0    20.0
# 20    DeepFace  LFW_gender_makeup_light    58.0       79.0    22.0
# 21    DeepFace  LFW_gender_makeup_light    60.0       92.0    22.0
# 22     ArcFace  LFW_gender_makeup_light    88.0       99.0    77.0
# 23     ArcFace  LFW_gender_makeup_light    90.0      100.0    81.0
# 24  Facenet512     LFW_gender_moustache    82.0       96.0    66.0
# 25  Facenet512     LFW_gender_moustache    77.0      100.0    54.0
# 26     Facenet     LFW_gender_moustache    66.0       99.0    31.0
# 27     Facenet     LFW_gender_moustache    64.0      100.0    28.0
# 28    VGG-Face     LFW_gender_moustache    73.0       73.0    74.0
# 29    VGG-Face     LFW_gender_moustache    76.0       98.0    54.0
# 30    OpenFace     LFW_gender_moustache    55.0       96.0    10.0
# 31    OpenFace     LFW_gender_moustache    56.0      100.0    11.0
# 32    DeepFace     LFW_gender_moustache    47.0       45.0    27.0
# 33    DeepFace     LFW_gender_moustache    50.0       50.0    23.0
# 34     ArcFace     LFW_gender_moustache    79.0      100.0    59.0
# 35     ArcFace     LFW_gender_moustache    76.0      100.0    52.0
# 36  Facenet512       LFW_gender_glasses    71.0       79.0    58.0
# 37  Facenet512       LFW_gender_glasses    76.0       96.0    55.0
# 38     Facenet       LFW_gender_glasses    49.0       49.0    43.0
# 39     Facenet       LFW_gender_glasses    51.0       52.0    39.0
# 40    VGG-Face       LFW_gender_glasses    75.0       77.0    72.0
# 41    VGG-Face       LFW_gender_glasses    85.0       99.0    72.0
# 42    OpenFace       LFW_gender_glasses    52.0       88.0     5.0
# 43    OpenFace       LFW_gender_glasses    53.0       80.0     7.0
# 44    DeepFace       LFW_gender_glasses    59.0       95.0    19.0
# 45    DeepFace       LFW_gender_glasses    58.0       95.0    16.0
# 46     ArcFace       LFW_gender_glasses    49.0       50.0    90.0
# 47     ArcFace       LFW_gender_glasses    47.0       48.0    85.0
#
#     Total Images  Gender   TP   TN   FP   FN  Undetected
# 0           1000    Male  398  476   24  102           0
# 1           1000  Female  366  498    2  134           0
# 2           1000    Male  174  500    0  326           0
# 3           1000  Female  192  500    0  308           0
# 4           1000    Male  404  327  173   96           0
# 5           1000  Female  346  487   13  154           0
# 6           1000    Male   38  498    2  462           0
# 7           1000  Female   60  500    0  440           0
# 8           1000    Male  127  422   78  373           0
# 9           1000  Female  110  471   29  390           0
# 10          1000    Male  377  494    6  123           0
# 11          1000  Female  365  498    2  135           0
# 12          1000    Male  413  472   28   87           0
# 13          1000  Female  405  498    2   95           0
# 14          1000    Male  220  500    0  280           0
# 15          1000  Female  216  500    0  284           0
# 16          1000    Male  421  264  236   79           0
# 17          1000  Female  360  474   26  140           0
# 18          1000    Male   21  497    3  479           0
# 19          1000  Female   98  500    0  402           0
# 20          1000    Male  111  470   30  389           0
# 21          1000  Female  112  490   10  388           0
# 22          1000    Male  384  495    5  116           0
# 23          1000  Female  404  499    1   96           0
# 24          1000    Male  330  487   13  170           0
# 25          1000  Female  270  500    0  230           0
# 26          1000    Male  156  499    1  344           0
# 27          1000  Female  138  500    0  362           0
# 28          1000    Male  369  364  136  131           0
# 29          1000  Female  268  494    6  232           0
# 30          1000    Male   48  498    2  452           0
# 31          1000  Female   55  500    0  445           0
# 32          1000    Male  135  335  165  365           0
# 33          1000  Female  116  384  116  384           0
# 34          1000    Male  293  499    1  207           0
# 35          1000  Female  262  500    0  238           0
# 36          1000    Male  289  421   79  211           0
# 37          1000  Female  274  490   10  226           0
# 38          1000    Male  213  279  221  287           0
# 39          1000  Female  193  321  179  307           0
# 40          1000    Male  360  391  109  140           0
# 41          1000  Female  358  495    5  142           0
# 42          1000    Male   23  497    3  477           0
# 43          1000  Female   33  492    8  467           0
# 44          1000    Male   94  495    5  406           0
# 45          1000  Female   80  496    4  420           0
# 46          1000    Male  448   46  454   52           0
# 47          1000  Female  423   46  454   77           0

# %% [markdown]
# ## Parameter setup:
#
# - Dataset
#
# - Model
#
# - Metric
#
# - Backend
#
# - Testing gender

# %%
# select a DATASET from data folder:
# LFW_gender: Gender split LFW dataset
# LFW_gender_makeup_heavy: Gender split LFW dataset with Heavy makeup
# LFW_gender_makeup_light: Gender split LFW dataset with Light makeup
# LFW_gender_moustache: Gender split LFW dataset with moustache 
# LFW_gender_glasses: Gender split LFW dataset with glasses 
DATASET_ORG = "LFW_gender"  # original dataset with gender splitted 
DATASET = "LFW_gender_moustache"
dataset_dir = f"./data/deepface_{DATASET_ORG}/{DATASET}"

# select a model to run:
# models = ["Facenet512", "Facenet", "VGG-Face", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib", "SFace"]
MODEL = "Facenet512"

# Faces are represented as vectors, a face pair of same person should be similar, calculated by different metrics
# metrics = ["cosine", "euclidean", "euclidean_l2"]
METRIC = "euclidean_l2"

# Face detector, backend that helps aligning the face for better accuracy
# backends = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface', 'mediapipe']
BACKEND = 'opencv'

# Select 'Male' or 'Female'
TEST_GENDER = 'Male'

# Image name 
# Luis_Ernesto_Derbez_Bautista, Junichiro_Koizumi, Vicente_Fox, Pierce_Brosnan, 
# Angelina_Jolie, Mariangel_Ruiz_Torrealba, Venus_Williams, Kate_Hudson
IMAGE_NAME = "Luis_Ernesto_Derbez_Bautista"

# %% [markdown]
# ### Deepface Demo testing:

# %% [markdown]
# #### Facial Analysis for gender predection:
#
# - Predicts the gender of the image

# %%
def deepface_gender_test(multiple=False):

    data_people = f"./data/deepface_{DATASET_ORG}/{DATASET}/{TEST_GENDER}/{IMAGE_NAME}"
    # Deepface Test one single image gender prediction 
    if not multiple:
        # sample image
        data_images = os.listdir(data_people)
        data_image = f"{data_people}/{rd.sample(data_images, 1).pop()}"   ### can manual select image from here  ###
        data_res = DeepFace.analyze(data_image, actions =["gender"], enforce_detection=False)

        # Show result: 
        print(data_res)
        plt.imshow(plt.imread(data_image))

        return {"Data directory": data_image, "Gender": data_res['gender']}

    # Deepface Test multiple images gender prediction 
    else:
        for i in os.listdir(data_people):
            data_image = f"{data_people}/{i}"
            data_res = DeepFace.analyze(data_image, actions =["gender"], enforce_detection=False)

            # Show result: 
            print(data_res)
            plt.imshow(plt.imread(data_image))

# %%
df_gender_res = deepface_gender_test()
# Out:
# 1/1 [==============================] - 0s 492ms/step
# {'gender': 'Man', 'region': {'x': 64, 'y': 65, 'w': 119, 'h': 119}}

# %% [markdown]
# ### Output and Save results

# %%
result_new = pd.DataFrame([df_gender_res])

frames = [result_gui_gender, result_new]
result_gui_new = pd.concat(frames)

result_gui_new = result_gui_new.reset_index()
result_gui_new.drop(columns=['index'], inplace=True)
result_gui_new
# Out:
#                                        Data directory Gender
# 0   ./data/LFW/Luis_Ernesto_Derbez_Bautista/Luis_E...    Man
# 1   ./data/LFW/Angelina_Jolie/Angelina_Jolie_0002.jpg  Woman
# 2   ./data/LFW_gender_makeup_light/Male/Junichiro_...    Man
# 3   ./data/LFW_gender_makeup_light/Female/Mariange...  Woman
# 4   ./data/LFW_gender_makeup_heavy/Male/Vicente_Fo...    Man
# 5   ./data/LFW_gender_makeup_heavy/Female/Venus_Wi...    Man
# 6   ./data/LFW_gender_moustache/Male/Michael_Chikl...    Man
# 7   ./data/LFW_gender_moustache/Female/Tyra_Banks/...  Woman
# 8   ./data/LFW_gender_glasses/Male/Keith_Bogans/Ke...    Man
# 9   ./data/LFW_gender_glasses/Female/Claire_Hentze...    Man
# 10  ./data/deepface_LFW_gender/LFW_gender_moustach...    Man

# %%
# Output result to CSV and read results
result_gui_new.to_csv("../DeepFace-gender-bias-detection/result/deepface_gui_gender.csv", index=False)
result_gui_gender = pd.read_csv('../DeepFace-gender-bias-detection/result/deepface_gui_gender.csv')

# %% [markdown]
# ## Deepface Facial Recognition with verification:
# - Verifies the face with 1 to 1 testing method according to the LFW benchmark test

# %%
unit_test_df = pd.read_csv('../DeepFace-gender-bias-detection/data/LFW-csv/unit_test_deepface.csv')
deepface_benchmark_res, perturbed_data = deepface_benchmark_lfw_split(DATASET, dataset_dir, unit_test_df,\
                                                                     MODEL, METRIC, BACKEND, TEST_GENDER)
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 92ms/step

# %%
print(f"Accuracy of {deepface_benchmark_res['Model']} is {deepface_benchmark_res['CM_ACC']}% \
for {deepface_benchmark_res['Gender']} in {deepface_benchmark_res['Dataset']} dataset")
# Out:
# Accuracy of Facenet512 is 100.0% for Male in LFW_gender dataset

# %% [markdown]
# ### Cross validation test:
# - Verifies the face with 1 to Many testing method

# %%
def deepface_face_recognition_test():
    # Get the images from the person
    data_people = f"../DeepFace-gender-bias-detection/data/deepface_{DATASET_ORG}/{DATASET}/{TEST_GENDER}/{IMAGE_NAME}"
    data_images = []
    for image in os.listdir(data_people):
        data_images.append(f"{data_people}/{image}")
        
    # Test Deepface face recognition with face verification 
    result = []
    
    if len(data_images) > 1:
    
        # Select target image
        for image_index in range(len(data_images)):
            truths = []
            target_image = data_images[image_index]

            for img in data_images:
                data_res = DeepFace.verify(target_image, img, model_name = MODEL, 
                                            distance_metric = METRIC, detector_backend = BACKEND, enforce_detection=False)
                truths.append(data_res["verified"])

            accuracy = round(sum(truths) / (len(data_images)), 2) * 100
            result.append({f"{target_image}": accuracy})
    else:
        raise Exception("Image folder contains less than 2 images")

    overall_accuracy = round(sum([list(i.values())[0] for i in result]) / len(result), 2)

    return {"Model": MODEL, "Accuracy": overall_accuracy, "Gender": TEST_GENDER}, result

# %%
df_face_recognition_res, result = deepface_face_recognition_test()
# Out:
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 88ms/step

# %%
for res in result:
    print(res)

print(f"\nAccuracy of {df_face_recognition_res['Model']} is {df_face_recognition_res['Accuracy']}")
# Out:
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0001.jpg': 77.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0002.jpg': 46.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0003.jpg': 85.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0004.jpg': 69.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0005.jpg': 77.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0006.jpg': 23.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0007.jpg': 77.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0008.jpg': 77.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0009.jpg': 15.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0010.jpg': 31.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0011.jpg': 77.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0012.jpg': 77.0}
# {'../DeepFace-gender-bias-detection/data/LFW_gender_moustache/Female/Salma_Hayek/Salma_Hayek_0013.jpg': 77.0}
#
# Accuracy of Facenet512 is 62.15

# %% [markdown]
# ## Output and read results to CSV

# %%
result_new = pd.DataFrame([df_face_recognition_res])

frames = [result_gui_face_recognition, result_new]
result_gui_new_fr = pd.concat(frames)

result_gui_new_fr = result_gui_new_fr.reset_index()
result_gui_new_fr.drop(columns=['index'], inplace=True)
result_gui_new_fr
# Out:
#          Model  Accuracy  Gender
# 0   Facenet512    100.00    Male
# 1   Facenet512     95.00  Female
# 2   Facenet512     98.00    Male
# 3   Facenet512    100.00  Female
# 4   Facenet512     94.00    Male
# 5   Facenet512    100.00  Female
# 6      Facenet     75.00    Male
# 7      Facenet     77.00  Female
# 8      Facenet     60.00    Male
# 9      Facenet     73.00  Female
# 10     Facenet     72.00    Male
# 11     Facenet     75.00  Female
# 12    VGG-Face     75.00    Male
# 13    VGG-Face     86.00  Female
# 14    VGG-Face     72.00    Male
# 15    VGG-Face     87.00  Female
# 16    VGG-Face     68.00    Male
# 17    VGG-Face     83.00  Female
# 18    Openface     53.00    Male
# 19    Openface     58.00  Female
# 20    Openface     50.00    Male
# 21    Openface     62.00  Female
# 22    Openface     52.00    Male
# 23    Openface     60.00  Female
# 24    Deepface     56.00    Male
# 25    Deepface     58.00  Female
# 26    Deepface     53.00    Male
# 27    Deepface     60.00  Female
# 28    Deepface     55.00    Male
# 29    Deepface     58.00  Female
# 30     Arcface     91.00    Male
# 31     Arcface     89.00  Female
# 32     Arcface     86.00    Male
# 33     Arcface     90.00  Female
# 34     Arcface     88.00    Male
# 35     Arcface     90.00  Female
# 36  Facenet512     89.93    Male

# %%
# Output result to CSV and read results
result_gui_new_fr.to_csv("../DeepFace-gender-bias-detection/result/deepface_gui_face_recognition.csv", index=False)
result_gui_face_recognition = pd.read_csv('../DeepFace-gender-bias-detection/result/deepface_gui_face_recognition.csv')
