# %%
# !pip install deepface
from deepface import DeepFace

import matplotlib.pyplot as plt
import pandas as pd 

params = {"ytick.color" : "w",
          "xtick.color" : "w",
          "axes.labelcolor" : "w",
          "axes.edgecolor" : "w"}
plt.rcParams.update(params)

# %%
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib", "SFace"]

model_used = "ArcFace"

# %%
img_path_1 = "./additional-data/yes-i-am-tzuyu-2.jpg"
img_path_2 = "./additional-data/yes-i-am-tzuyu-3.jpg"

# %%
img_1 = DeepFace.detectFace(img_path_1)
img_2 = DeepFace.detectFace(img_path_2)

# %%
obj = DeepFace.analyze(img_path = img_path_1, actions = ['age', 'gender'])
# Out:
# ...
# Action: gender: 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]

# %%
plt.imshow(img_1)
obj
# Out:
# {'age': 31,
#  'region': {'x': 293, 'y': 277, 'w': 187, 'h': 187},
#  'gender': 'Woman'}

# %%
df = DeepFace.find(img_path = img_1, db_path = "C:/workspace/my_db", model_name = model_used)
# Out:
# 1/1 [==============================] - 0s 113ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10920\1868995730.py in <cell line: 1>()
# ----> 1 df = DeepFace.find(img_path = img_1, db_path = "C:/workspace/my_db", model_name = model_used)
#
# c:\Users\ASUS\anaconda3\envs\DebFaceVE\lib\site-packages\deepface\DeepFace.py in find(img_path, db_path, model_name, distance_metric, model, enforce_detection, detector_backend, align, prog_bar, normalization, silent)
#     579                                         custom_model = models[j]
#     580
# --> 581 					representation = represent(img_path = employee
#     582                                                 , model_name = model_name, model = custom_model
#     583                                                 , enforce_detection = enforce_detection, detector_backend = detector_backend
#
# ...

# %%
result = DeepFace.verify(img1_path = img_path_1, img2_path = img_path_2, model_name=model_used)
# Out:
# ...
# 1/1 [==============================] - 0s 128ms/step

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.5323641410519615,
#  'threshold': 0.68,
#  'model': 'ArcFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}
